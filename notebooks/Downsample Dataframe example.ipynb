# %%
import pandas as pd
import singlecellmultiomics.countTableProcessing.downsampleDataFrame as ds

# %%
import string
import numpy as np
# Generate random matrix:
df = pd.DataFrame( { f'cell_{x}':{ y:np.random.randint(0,5) for y in string.ascii_uppercase } for x in string.ascii_uppercase})
df
# Out:
#    cell_A  cell_B  cell_C  cell_D  cell_E  cell_F  cell_G  cell_H  cell_I  \
# A       1       4       2       1       1       4       4       2       0
# B       4       1       0       4       4       3       2       2       4
# C       4       2       4       0       1       2       0       4       4
# D       4       0       4       2       1       2       2       2       3
# E       3       3       2       4       1       2       1       3       2
# F       2       0       2       1       0       2       4       2       1
# G       0       4       3       3       2       1       0       0       4
# H       2       3       1       3       1       4       0       0       4
# I       3       2       2       3       2       4       0       1       1
# J       4       4       2       2       1       4       4       3       4
# K       3       4       0       2       2       1       4       4       1
# L       4       0       1       4       4       2       2       2       0
# ...

# %%
# %matplotlib notebook
downsample_to = 50
import matplotlib.pyplot as plt
fig, ax  = plt.subplots()
df.sum().plot.hist(ax =ax)
ax.axvline(downsample_to, c='r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Downsample to 30 per cell, min presence of 10 counts per gene
ds.downsampleDataFrame(df, 30, 0)
# Out:
#    cell_A  cell_B  cell_C  cell_D  cell_E  cell_F  cell_G  cell_H  cell_I  \
# A       0       3       0       0       0       2       2       1       0
# B       2       1       0       4       3       3       2       2       2
# C       2       0       3       0       1       1       0       3       4
# D       1       0       2       0       1       1       1       0       1
# E       0       2       2       3       1       0       1       2       1
# F       1       0       0       1       0       1       1       1       1
# G       0       0       2       0       0       1       0       0       2
# H       1       3       1       2       1       3       0       0       3
# I       3       2       1       3       2       3       0       0       1
# J       3       3       2       2       1       1       0       2       2
# K       3       1       0       1       2       1       4       0       0
# L       2       0       0       1       3       2       1       1       0
# ...
